# %%
import pandas as pd
import numpy as np
df = pd.read_excel(r'C:\Users\Владос\Desktop\ВКР\rezy_intervyu.xlsx', sep=';')

# %%
df.dropna()
df.head()
# Out:
#   Respondent  Online impulse purchase of apparel eperience  \
# 0      Irina                                             1
# 1     Nikita                                             1
# 2       Kate                                             1
# 3       Yana                                             1
# 4  Anastasia                                             1
#
#    Price, discount and sales  Bonus and promotion  Scarcity  Atmospheric cues  \
# 0                          1                    0         0                 1
# 1                          1                    0         0                 1
# 2                          1                    1         0                 1
# 3                          1                    1         1                 1
# 4                          1                    1         1                 1
#
#    Recommendation agent  Social presence  Telepresence  \
# 0                     0                1             1
# ...

# %%
import matplotlib.pyplot as plt
from pandas import ExcelWriter
plt.matshow(df.corr())

df.corr()
# Out:
#                                               Online impulse purchase of apparel eperience  \
# Online impulse purchase of apparel eperience                                           NaN
# Price, discount and sales                                                              NaN
# Bonus and promotion                                                                    NaN
# Scarcity                                                                               NaN
# Atmospheric cues                                                                       NaN
# Recommendation agent                                                                   NaN
# Social presence                                                                        NaN
# Telepresence                                                                           NaN
# Personalization and customized view                                                    NaN
# ...

# %%
import statsmodels.api as sm

X = df["Gender"]
y = df["Scarcity"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Scarcity   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     2.053
# Date:                Sun, 24 Mar 2019   Prob (F-statistic):              0.160
# Time:                        16:37:11   Log-Likelihood:                -41.869
# No. Observations:                  40   AIC:                             85.74
# Df Residuals:                      39   BIC:                             87.43
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Gender         0.2500      0.174      1.433      0.160      -0.103       0.603
# ...

# %%
import statsmodels.api as sm

X = df["Gender"]
y = df["Telepresence"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Telepresence   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     2.716
# Date:                Sun, 24 Mar 2019   Prob (F-statistic):              0.107
# Time:                        16:37:12   Log-Likelihood:                -45.195
# No. Observations:                  40   AIC:                             92.39
# Df Residuals:                      39   BIC:                             94.08
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Gender         0.3125      0.190      1.648      0.107      -0.071       0.696
# ...

# %%
import statsmodels.api as sm

X = df["Gender"]
y = df["Search mechanism "]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      Search mechanism    R-squared:                       0.432
# Model:                            OLS   Adj. R-squared:                  0.418
# Method:                 Least Squares   F-statistic:                     29.71
# Date:                Sun, 24 Mar 2019   Prob (F-statistic):           2.99e-06
# Time:                        17:32:47   Log-Likelihood:                -43.870
# No. Observations:                  40   AIC:                             89.74
# Df Residuals:                      39   BIC:                             91.43
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Gender         1.0000      0.183      5.451      0.000       0.629       1.371
# ...

# %%
import statsmodels.api as sm

X = df["Gender"]
y = df["Variety of selection"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Variety of selection   R-squared:                       0.087
# Model:                              OLS   Adj. R-squared:                  0.063
# Method:                   Least Squares   F-statistic:                     3.707
# Date:                  Sun, 24 Mar 2019   Prob (F-statistic):             0.0615
# Time:                          17:33:33   Log-Likelihood:                -38.971
# No. Observations:                    40   AIC:                             79.94
# Df Residuals:                        39   BIC:                             81.63
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm

X = df["Gender"]
y = df["Return policy"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          Return policy   R-squared:                       0.236
# Model:                            OLS   Adj. R-squared:                  0.217
# Method:                 Least Squares   F-statistic:                     12.07
# Date:                Sun, 24 Mar 2019   Prob (F-statistic):            0.00127
# Time:                        17:34:02   Log-Likelihood:                -46.902
# No. Observations:                  40   AIC:                             95.80
# Df Residuals:                      39   BIC:                             97.49
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Gender         0.6875      0.198      3.474      0.001       0.287       1.088
# ...

# %%
import statsmodels.api as sm

X = df["Earnings"]
y = df["Price, discount and sales"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     Price, discount and sales   R-squared:                       0.550
# Model:                                   OLS   Adj. R-squared:                  0.538
# Method:                        Least Squares   F-statistic:                     47.65
# Date:                       Sun, 24 Mar 2019   Prob (F-statistic):           2.92e-08
# Time:                               17:30:56   Log-Likelihood:                -39.233
# No. Observations:                         40   AIC:                             80.47
# Df Residuals:                             39   BIC:                             82.15
# Df Model:                                  1
# Covariance Type:                   nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm

X = df["Earnings"]
y = df["Social presence"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Social presence   R-squared:                       0.371
# Model:                            OLS   Adj. R-squared:                  0.354
# Method:                 Least Squares   F-statistic:                     22.96
# Date:                Sun, 24 Mar 2019   Prob (F-statistic):           2.42e-05
# Time:                        17:34:59   Log-Likelihood:                -41.747
# No. Observations:                  40   AIC:                             85.49
# Df Residuals:                      39   BIC:                             87.18
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Earnings       0.6538      0.136      4.791      0.000       0.378       0.930
# ...

# %%
import statsmodels.api as sm

X = df["Earnings"]
y = df["Search mechanism "]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      Search mechanism    R-squared:                       0.550
# Model:                            OLS   Adj. R-squared:                  0.538
# Method:                 Least Squares   F-statistic:                     47.65
# Date:                Sun, 24 Mar 2019   Prob (F-statistic):           2.92e-08
# Time:                        17:35:27   Log-Likelihood:                -39.233
# No. Observations:                  40   AIC:                             80.47
# Df Residuals:                      39   BIC:                             82.15
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Earnings       0.8846      0.128      6.903      0.000       0.625       1.144
# ...

# %%
import statsmodels.api as sm

X = df["Telepresence"]
y = df["Income"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.607
# Method:                 Least Squares   F-statistic:                     62.66
# Date:                Sun, 24 Mar 2019   Prob (F-statistic):           1.23e-09
# Time:                        17:48:15   Log-Likelihood:                -70.951
# No. Observations:                  40   AIC:                             143.9
# Df Residuals:                      39   BIC:                             145.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm

X = df["Return policy"]
y = df["Income"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.807
# Model:                            OLS   Adj. R-squared:                  0.802
# Method:                 Least Squares   F-statistic:                     163.3
# Date:                Sun, 24 Mar 2019   Prob (F-statistic):           1.61e-15
# Time:                        17:36:29   Log-Likelihood:                -57.190
# No. Observations:                  40   AIC:                             116.4
# Df Residuals:                      39   BIC:                             118.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
df = pd.read_excel(r'C:\Users\Владос\Desktop\ВКР\rezy_intervyu.xlsx', sep=';')
import statsmodels.api as sm
f1=[]
f2=[]
df = df.drop('Respondent', axis=1)
for i in df.columns:
    for j in df.columns.drop(i):
        print(i,j)
        f1.append(i)
        f2.append(j)

my_dict = dict(zip(f1, f2))  
for i,j in my_dict.items():
    X = df[i]
    y = df[j]
    # Note the difference in argument order
    model = sm.OLS(y, X.astype(float)).fit()
    predictions = model.predict(X) # make the predictions by the model

    # Print out the statistics
    model.summary()
# Out:
#     Online impulse purchase of apparel eperience  Price, discount and sales  \
# 0                                              1                          1
# 1                                              1                          1
# 2                                              1                          1
# 3                                              1                          1
# 4                                              1                          1
# 5                                              1                          1
# 6                                              1                          1
# 7                                              1                          1
# 8                                              1                          1
# 9                                              1                          1
# 10                                             1                          1
# ...

# %%
f1=[]
f2=[]
for i in df.columns:
    
    X = df[i]
    
    for j in df.columns.drop(i):
        y = df[j]
        f1.append(i)
        f2.append(j)

my_dict = dict(zip(f1, f2))

# %%
my_dict
# Out:
# {'Online impulse purchase of apparel eperience': 'Financial situation',
#  'Price, discount and sales': 'Financial situation',
#  'Bonus and promotion': 'Financial situation',
#  'Scarcity': 'Financial situation',
#  'Atmospheric cues': 'Financial situation',
#  'Recommendation agent': 'Financial situation',
#  'Social presence': 'Financial situation',
#  'Telepresence': 'Financial situation',
#  'Personalization and customized view': 'Financial situation',
#  'Search mechanism ': 'Financial situation',
#  'Variety of selection': 'Financial situation',
#  'Return policy': 'Financial situation',
#  'Gender': 'Financial situation',
#  'Earnings': 'Financial situation',
#  'Financial situation': 'Earnings'}
